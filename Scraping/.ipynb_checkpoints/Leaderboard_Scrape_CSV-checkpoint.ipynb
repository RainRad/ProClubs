# %%
import sys
sys.path.insert(0, '../Resources')
import MyFunctionsList as mfs

import datetime
import requests
import pandas as pd
from bs4 import BeautifulSoup as soup


# Debugging
import time
from IPython.display import display, clear_output

# %%
# Debug
start_time = time.time()

# Creates a dictionary to fill later. Key = Console, Value = [List of Clubs]
final_multi_console_ids = {}

consoles = ["xboxone", "ps4","xbsxs","ps5","pc"]

# Iterate through each console's top 100
for console in consoles:
    
    console_id_list = []
    # Construct URL, Scrape Website
    url = f"https://proclubshead.com/23/leaderboard-club/{console}"
    site = mfs.scrape(url)
    
    for club in site.find_all("a", class_="btn btn-secondary d-block mb-3 p-0", href=True):
        club_link = club['href']
        club_id = mfs.simple_link_stripper(club_link)
        console_id_list.append(club_id)        
    final_multi_console_ids[console] = console_id_list
    
    
# Debug
end_time = time.time()
print("Time taken:", end_time - start_time, "seconds")
# Out:
# Time taken: 4.1389758586883545 seconds

# %%
# Debug
start_time = time.time()
length  = 0
for console in final_multi_console_ids:
    length += len(final_multi_console_ids[console])
counter = 0

# Iterate through each console. 
final_club_data_list = []


for console in final_multi_console_ids:
    
    #Iterate through each club. 
    for club in final_multi_console_ids[console]:
        print(club)
        club_data = mfs.club_scrape(console, club)
        final_club_data_list.append(club_data)
        
        #debug
        clear_output(wait=True)
        counter += 1
        print(f"{counter}/{length}")
        
# Debug
end_time = time.time()
print("Time taken:", end_time - start_time, "seconds")
# Out:
# 495/495
# Time taken: 394.09196519851685 seconds

# %%
#Generates and stores current time for later use. 
current_time = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')

# %%
Top_Clubs = pd.DataFrame(final_club_data_list)

Top_Clubs.insert(0, 'pull_time', current_time)

Top_Clubs.head()
# Out:
#              pull_time        club_name active  console   club_id  division  \
# 0  2023-04-16 18:34:23  Bang Average FC    Yes  xboxone   1940614         1
# 1  2023-04-16 18:34:23         FootieXI    Yes  xboxone   4339359         1
# 2  2023-04-16 18:34:23       NO TRUENES    Yes  xboxone   3705104         1
# 3  2023-04-16 18:34:23        rock club    Yes  xboxone    542709         2
# 4  2023-04-16 18:34:23     XVC AC MILAN    Yes  xboxone  10205899         1
#
#   ten_match_record  total_games  wins  losses  ...  best_season_div  \
# 0       WWWWWWWWWW          635   495      75  ...                1
# 1       WWWWWWWWWD          625   509      58  ...                1
# 2       WWWWWWWWLD          572   474      59  ...                1
# 3       WWWWLLLLLL         1549  1097     203  ...                1
# 4       WWWWWWWWLD          328   270      21  ...                1
#
#    best_season_points           region                    stadium  \
# 0                  25    British Isles  Estadio Santiago Bernabéu
# 1                  25    British Isles               Old Trafford
# 2                  25  Central America       ESTADIO DE TRONACION
# 3                  25    British Isles        Johan Cruijff ArenA
# 4                  25    British Isles               Old Trafford
#
#    total_rank_points  league_points  cup_points  div_1_titles  \
# 0              19045          19045           0            43
# 1              20309          20309           0            51
# 2              19169          19169           0            49
# 3              42008          42008           0            94
# 4               9773           9773           0            21
#
#    other_div_titles  total_trophies
# 0                 8              51
# 1                 9              60
# 2                 9              58
# 3                 5              99
# 4                 9              30
#
# [5 rows x 29 columns]

# %%
# Optional
Top_Clubs.to_csv("../CollectedData/Top_Clubs.csv", index=False)
