# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.ensemble import RandomForestClassifier
import numpy as np

# %%
# Import ML ready data. 
data = pd.read_csv('model_ready_match_data.csv')
data.head()
data = data.drop(["pass_percent", "shot_percent", 'tackle_percent'], axis=1)

# %%
# Split the Data into X, Y
X = data.drop("result", axis=1)
y = data.result

# %%
# Train Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
# Generate the Model
classifier = RandomForestClassifier(n_estimators=500, criterion ='entropy', random_state = 1)

# %%
# Train the model
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=500, random_state=1)

# %%
# Predict the test data
y_pred = classifier.predict(X_test)
y_pred
# Out:
# array([1, 0, 1, ..., 0, 0, 0], dtype=int64)

# %%
# Generate confusion matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[8000 1631]
#  [1778 5007]]

# %%
# Output Accuracy score
accuracy_score(y_test, y_pred)
# Out:
# 0.7923367446393762

# %%
# Print Classifcation report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.83      0.82      9631
#            1       0.75      0.74      0.75      6785
#
#     accuracy                           0.79     16416
#    macro avg       0.79      0.78      0.79     16416
# weighted avg       0.79      0.79      0.79     16416

# %%
# Generate the Feature importance
classifier.feature_importances_
# Out:
# array([0.31253948, 0.10617543, 0.12766771, 0.132141  , 0.07544113,
#        0.1147236 , 0.00936519, 0.03348691, 0.02923844, 0.03125738,
#        0.01398705, 0.00728555, 0.00669114])

# %%
# Generate bar graph of feature importance. 
importance = classifier.feature_importances_
columns = X_train.columns
combined_features = pd.Series(importance, columns)

# sort the combined_features series in descending order
combined_features_sorted = combined_features.sort_values(ascending=False)

# plot the sorted series
pandas_plot = combined_features_sorted.plot.bar(figsize=(15,6), color='b', fontsize = 12)
plt.xlabel("columns", fontsize = 12)
plt.xticks(rotation = 30)
plt.ylabel("importance", fontsize = 12)
plt.title("Important Contributors", fontsize = 18)
plt.tight_layout()
plt.show()
